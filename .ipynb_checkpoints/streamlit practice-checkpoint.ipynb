# %%
import streamlit as st

# %%
st.write("Hello world")
# Out:
# 2021-05-06 11:58:36.568 WARNING root:
# ...
#   command:
#
#     streamlit run C:\Users\tamir\anaconda\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
