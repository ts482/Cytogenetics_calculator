# %%
import re
import pandas as pd
import streamlit as st
import base64

# %% [markdown]
# # identifying karyotype reports

# %%
st.write('# Cytogenetics calculator')

# %%
def load_file(file= 'Cytogenetics_TS_Apr2021.xlsx', streamlit=False):
    '''
    Loads the excel file and drops the ID column
    
    Params:
    -------
    
    file: excel filepath
        the file containing the cytogenetic reports, with columns
        that contain information about details to fill
        
    streamlit: bool, default False
        whether the streamlit interface should be used
    '''
    if streamlit:
        file = st.file_uploader("Upload excel here")
    karyotypes = pd.read_excel(file)    
    karyotypes = karyotypes.drop(columns='ID')
    
    return karyotypes

# %%
load_file().head()
# Out:
#                        Cytogenetics  Number of cytogenetic abnormalities  \
# 0                  46,XX[25]_x000D_                                  NaN
# 1         46,XY,del(11)(q14q23)[10]                                  NaN
# 2   46,XX,del(5)(q22q35)[8/46,XX[2]                                  NaN
# 3              45,X,-Y[17]/46,XY[3]                                  NaN
# 4              47,XY,+8[9]/46,XY[1]                                  NaN
#
#    Monosomy  Structural  "-Y"  "-X"  del11q  del12p  del13q  del5q  ...  \
# 0       NaN         NaN   NaN   NaN     NaN     NaN     NaN    NaN  ...
# 1       NaN         NaN   NaN   NaN     NaN     NaN     NaN    NaN  ...
# 2       NaN         NaN   NaN   NaN     NaN     NaN     NaN    NaN  ...
# 3       NaN         NaN   NaN   NaN     NaN     NaN     NaN    NaN  ...
# 4       NaN         NaN   NaN   NaN     NaN     NaN     NaN    NaN  ...
#
#    t(9;22)  t(16;16)  inv(16)  t(8;21)  t(15;17)  t(9;11)  t(6;11)  t(10;11)  \
# 0      NaN       NaN      NaN      NaN       NaN      NaN      NaN       NaN
# 1      NaN       NaN      NaN      NaN       NaN      NaN      NaN       NaN
# 2      NaN       NaN      NaN      NaN       NaN      NaN      NaN       NaN
# 3      NaN       NaN      NaN      NaN       NaN      NaN      NaN       NaN
# 4      NaN       NaN      NaN      NaN       NaN      NaN      NaN       NaN
#
#    t(v;11)  abnormal(17p)
# 0      NaN            NaN
# 1      NaN            NaN
# 2      NaN            NaN
# 3      NaN            NaN
# 4      NaN            NaN
#
# [5 rows x 43 columns]

# %%
#karyotypes = pd.read_excel('Cytogenetics_TS_Apr2021.xlsx', )
#file = st.file_uploader("Upload excel here")
#karyotypes = pd.read_excel(file)
#karyotypes = karyotypes.drop(columns='ID')
karyotypes.head()
# Out:
#                        Cytogenetics  Number of cytogenetic abnormalities  \
# 0                  46,XX[25]_x000D_                                  NaN
# 1         46,XY,del(11)(q14q23)[10]                                  NaN
# 2   46,XX,del(5)(q22q35)[8/46,XX[2]                                  NaN
# 3              45,X,-Y[17]/46,XY[3]                                  NaN
# 4              47,XY,+8[9]/46,XY[1]                                  NaN
#
#    Monosomy  Structural  "-Y"  "-X"  del11q  del12p  del13q  del5q  ...  \
# 0       NaN         NaN   NaN   NaN     NaN     NaN     NaN    NaN  ...
# 1       NaN         NaN   NaN   NaN     NaN     NaN     NaN    NaN  ...
# 2       NaN         NaN   NaN   NaN     NaN     NaN     NaN    NaN  ...
# 3       NaN         NaN   NaN   NaN     NaN     NaN     NaN    NaN  ...
# 4       NaN         NaN   NaN   NaN     NaN     NaN     NaN    NaN  ...
#
#    t(16;16)  inv(16)  t(8;21)  t(15;17)  t(9;11)  t(6;11)  t(10;11)  t(v;11)  \
# 0       NaN      NaN      NaN       NaN      NaN      NaN       NaN      NaN
# 1       NaN      NaN      NaN       NaN      NaN      NaN       NaN      NaN
# 2       NaN      NaN      NaN       NaN      NaN      NaN       NaN      NaN
# 3       NaN      NaN      NaN       NaN      NaN      NaN       NaN      NaN
# 4       NaN      NaN      NaN       NaN      NaN      NaN       NaN      NaN
#
#    abnormal(17p)  Error description
# 0            NaN              False
# 1            NaN              False
# 2            NaN              False
# 3            NaN              False
# 4            NaN              False
#
# [5 rows x 44 columns]

# %%
karyotypes = load_file()
properties = karyotypes.columns[4:-1].to_list()

# %%
properties
# Out:
# ['"-Y"',
#  '"-X"',
#  'del11q',
#  'del12p',
#  'del13q',
#  'del5q',
#  'del7q',
#  'idic(X)(q13)',
#  'isochromosome17q',
#  'Monosomy13',
#  'Monosomy17',
#  'Monosomy5',
#  'Monosomy7',
#  't(1;3)',
#  't(11;16)(q23.3;p13.3)',
#  't(12p)',
#  't(17p)',
#  't(2;11)',
#  't(3;21)',
#  't(3;5)',
#  't(5;10)',
#  't(5;12)',
#  't(5;17)',
#  't(5;7)',
#  't(5q)',
#  't(1;22)',
#  'inv(3)',
#  't(3;3)',
#  't(6;9)',
#  't(9;22)',
#  't(16;16)',
#  'inv(16)',
#  't(8;21)',
#  't(15;17)',
#  't(9;11)',
#  't(6;11)',
#  't(10;11)',
#  't(v;11)']

# %%
def properties_dict(properties=properties):
    d = {p:p for p in properties}
    for k,v in d.items():
        #removing quotation marks at start and end
        if v[0] == '"':
            if v[-1] == v[0]:
                v = v[1:-1]
        
        #recognising monosomies
        if v.startswith('Monosomy'):
            v = '-' + v[8:]
            
        matches = re.finditer('(\d+)(p|q)',v)
        for m in matches:
            f = v[:m.start()] + '(' + m.group()[:-1] + \
                ')(' + m.group()[-1]+ v[m.end():]
            v=f
            
        #creating escape characters for strings
        v = re.escape(v)
        
        if v == 't\\(v;11\\)':
            v = 't\\(\d+;11\\)'
        
        d[k] = v
    return {v:k for k,v in d.items()}

# %%
prop_dict = properties_dict()
prop_dict
# Out:
# {'\\-Y': '"-Y"',
#  '\\-X': '"-X"',
#  'del\\(11\\)\\(q': 'del11q',
#  'del\\(12\\)\\(p': 'del12p',
#  'del\\(13\\)\\(q': 'del13q',
#  'del\\(5\\)\\(q': 'del5q',
#  'del\\(7\\)\\(q': 'del7q',
#  'idic\\(X\\)\\(q13\\)': 'idic(X)(q13)',
#  'isochromosome\\(17\\)\\(q': 'isochromosome17q',
#  '\\-13': 'Monosomy13',
#  '\\-17': 'Monosomy17',
#  '\\-5': 'Monosomy5',
#  '\\-7': 'Monosomy7',
#  't\\(1;3\\)': 't(1;3)',
#  't\\(11;16\\)\\(q23\\.3;p13\\.3\\)': 't(11;16)(q23.3;p13.3)',
#  't\\(\\(12\\)\\(p\\)': 't(12p)',
#  't\\(\\(17\\)\\(p\\)': 't(17p)',
#  't\\(2;11\\)': 't(2;11)',
#  't\\(3;21\\)': 't(3;21)',
#  't\\(3;5\\)': 't(3;5)',
#  't\\(5;10\\)': 't(5;10)',
#  't\\(5;12\\)': 't(5;12)',
#  't\\(5;17\\)': 't(5;17)',
#  't\\(5;7\\)': 't(5;7)',
#  't\\(\\(5\\)\\(q\\)': 't(5q)',
#  't\\(1;22\\)': 't(1;22)',
#  'inv\\(3\\)': 'inv(3)',
#  't\\(3;3\\)': 't(3;3)',
#  't\\(6;9\\)': 't(6;9)',
#  't\\(9;22\\)': 't(9;22)',
#  't\\(16;16\\)': 't(16;16)',
#  'inv\\(16\\)': 'inv(16)',
#  't\\(8;21\\)': 't(8;21)',
#  't\\(15;17\\)': 't(15;17)',
#  't\\(9;11\\)': 't(9;11)',
#  't\\(6;11\\)': 't(6;11)',
#  't\\(10;11\\)': 't(10;11)',
#  't\\(\\d+;11\\)': 't(v;11)'}

# %%
def remove_artefact(row):
    if re.search('_x000D_$', row['Cytogenetics']):
        return row['Cytogenetics'].strip()[:-7]
    return row['Cytogenetics'].strip()

# %%
karyotypes['Cytogenetics'] = karyotypes.apply(remove_artefact, axis=1)

# %%
karyotypes['Error'] = False

# %%
karyotypes['Error description'] = None

# %%
punct = r'()[]/'
punct_dict = {s:0 for s in punct}

# %%
def gram_error(string):
    missing = list()
    for k in punct_dict:
        punct_dict[k] = len(re.findall(re.escape(k), string))
    if punct_dict['/'] != punct_dict['[']-1:
        return 'incorrrect ratio of \'\\\' to \'[]\' '
    if punct_dict['['] != punct_dict[']']:
        missing.append(min(['[', ']'], key=punct_dict.get))
    if punct_dict['('] != punct_dict[')']:
        missing.append(min(['(',')'], key=punct_dict.get))
    if len(missing)!=0:
        return f'missing grammar: {", ".join(missing)}'
    substring = re.split('/', string)
    for i, s in enumerate(substring):
        chrom = s[:s.index(',')] #chromsome string
        if not re.search('idem', s):
            expected = 46
        expected -= len(re.findall('\-', s))
        expected += len(re.findall('\+', s))
        if re.search('[~]', s):
            low_num, high_num = int(chrom[:2]), int(chrom[-2:]) 
            if low_num <= expected <= high_num:
                pass
            elif expected < low_num:
                return f'chromsome number lower than expected in {i+1} subsection'
            else:
                return f'chromsome number higher than expected in {i+1} subsection'
        else:
            num = int(chrom[:2])
            if expected == num:
                pass
            elif expected > num:
                return f'chromsome number higher than expected in {i+1} subsection'
            else:
                return f'chromsome number lower than expected in {i+1} subsection'
    pass

# %%
def parse_karyotype(row):
    error = gram_error(row['Cytogenetics'])
    if error:
        row['Error'] = True
        row['Error description'] = error
        if not error.startswith('chromsome'):
            return row
    abnorms = set(re.split('/|,|\[', row['Cytogenetics']))
    removed = set()
    col_true = set()
    mono = 0
    struc = 0
    der = 0
    seventeen_p = False
    for a in abnorms:
        if re.fullmatch('\d\d([~-]\d\d)?|X[XY]?|(cp)?\d\d?\]|idem', a):
            removed.add(a)
#         if re.search('mar', a): #no longer the case to remove mar
#             removed.add(a)
        
        if a not in removed:
            
            if re.fullmatch('-\d+|-[XY]', a):
                mono += 1
            if re.search('[inv|t].*\).*\)', a):
                struc += 1
            
            if re.search('der', a):
                der += 1

            if re.search('17.*p|-17',a):
                m = re.search('\d\d?;\d\d?', a)
                if m:
                    split = re.split(';', m.group())
                    if re.findall('[pq]', a)[split.index('17')] == 'p':
                        seventeen_p = True
                    else:
                        seventeen_p = False
                else:
                    seventeen_p = True
            
            for p in prop_dict:
                if re.search(p, a):
                    col_true.add(p)
    abnorms = abnorms.difference(removed)
    row['Number of cytogenetic abnormalities'] = len(abnorms) + der
    row['Monosomy'] = mono
    row['Structural'] = struc
    row['abnormal(17p)'] = seventeen_p
    for c in col_true:
        row[prop_dict[c]] = True
    return row

# %%
results = karyotypes.apply(parse_karyotype, axis=1, )
results.head()
# Out:
#                       Cytogenetics  Number of cytogenetic abnormalities  \
# 0                        46,XX[25]                                  0.0
# 1        46,XY,del(11)(q14q23)[10]                                  1.0
# 2  46,XX,del(5)(q22q35)[8/46,XX[2]                                  NaN
# 3             45,X,-Y[17]/46,XY[3]                                  1.0
# 4             47,XY,+8[9]/46,XY[1]                                  1.0
#
#    Monosomy  Structural  "-Y"  "-X" del11q  del12p del13q del5q  ... inv(16)  \
# 0       0.0         0.0   NaN   NaN    NaN     NaN    NaN   NaN  ...     NaN
# 1       0.0         0.0   NaN   NaN   True     NaN    NaN   NaN  ...     NaN
# 2       NaN         NaN   NaN   NaN    NaN     NaN    NaN   NaN  ...     NaN
# 3       1.0         0.0  True   NaN    NaN     NaN    NaN   NaN  ...     NaN
# 4       0.0         0.0   NaN   NaN    NaN     NaN    NaN   NaN  ...     NaN
#
#    t(8;21)  t(15;17) t(9;11) t(6;11) t(10;11) t(v;11)  abnormal(17p)  \
# 0      NaN       NaN     NaN     NaN      NaN     NaN          False
# 1      NaN       NaN     NaN     NaN      NaN     NaN          False
# 2      NaN       NaN     NaN     NaN      NaN     NaN            NaN
# 3      NaN       NaN     NaN     NaN      NaN     NaN          False
# 4      NaN       NaN     NaN     NaN      NaN     NaN          False
#
#     Error description  Error
# 0                None  False
# 1                None  False
# 2  missing grammar: ]   True
# 3                None  False
# 4                None  False
#
# [5 rows x 45 columns]

# %%
results.loc[results['Error'].astype(bool)]
# Out:
#                                           Cytogenetics  \
# 2                      46,XX,del(5)(q22q35)[8/46,XX[2]
# 14                                45,X,-Y[6] 46,XY[14]
# 33   45-47,XY,add(3)(p13),-5,add(6)(p22),del(7)(q22...
# 69              46,XY,+1,der(1;7)(q10;p10)[9]/46,XY[4]
# 71   46,XY,-11,add(18)(q21),-20,add(20)(p12),+2mar[10]
# 78   43~47,X,-Y,add(1)(p36.3),-5,add(5)(q11.2),-8,a...
# 115     45,XX,-7[22]/46,idem,+12[3]/47,idem,+12,+20[5]
# 127  45,XX,add(4)(q31),-5,-6,-17,del(20)(q11.2q13.1...
# 147  46,XY,add(5)(q14),del(7)(q31q36),+8,?dup(10)(q...
#
#      Number of cytogenetic abnormalities  Monosomy  Structural  "-Y"  "-X"  \
# 2                                    NaN       NaN         NaN   NaN   NaN
# 14                                   NaN       NaN         NaN   NaN   NaN
# 33                                  10.0       3.0         0.0   NaN   NaN
# 69                                   3.0       0.0         0.0   NaN   NaN
# 71                                   5.0       2.0         0.0   NaN   NaN
# 78                                  15.0       8.0         0.0  True   NaN
# 115                                  3.0       1.0         0.0   NaN   NaN
# 127                                  6.0       3.0         0.0   NaN   NaN
# 147                                 13.0       3.0         0.0   NaN   NaN
#
#     del11q  del12p del13q del5q  ... inv(16)  t(8;21)  t(15;17) t(9;11)  \
# 2      NaN     NaN    NaN   NaN  ...     NaN      NaN       NaN     NaN
# 14     NaN     NaN    NaN   NaN  ...     NaN      NaN       NaN     NaN
# 33     NaN     NaN    NaN   NaN  ...     NaN      NaN       NaN     NaN
# 69     NaN     NaN    NaN   NaN  ...     NaN      NaN       NaN     NaN
# 71     NaN     NaN    NaN   NaN  ...     NaN      NaN       NaN     NaN
# 78     NaN     NaN    NaN   NaN  ...     NaN      NaN       NaN     NaN
# 115    NaN     NaN    NaN   NaN  ...     NaN      NaN       NaN     NaN
# 127    NaN     NaN    NaN   NaN  ...     NaN      NaN       NaN     NaN
# 147    NaN     NaN    NaN   NaN  ...     NaN      NaN       NaN     NaN
#
#     t(6;11) t(10;11) t(v;11)  abnormal(17p)  \
# 2       NaN      NaN     NaN            NaN
# 14      NaN      NaN     NaN            NaN
# 33      NaN      NaN     NaN           True
# 69      NaN      NaN     NaN          False
# 71      NaN      NaN     NaN          False
# 78      NaN      NaN     NaN           True
# 115     NaN      NaN     NaN          False
# 127     NaN      NaN     NaN           True
# 147     NaN      NaN     NaN          False
#
#                                      Error description  Error
# 2                                   missing grammar: ]   True
# 14                    incorrrect ratio of '\' to '[]'    True
# 33   chromsome number lower than expected in 1 subs...   True
# 69   chromsome number higher than expected in 1 sub...   True
# 71   chromsome number lower than expected in 1 subs...   True
# 78   chromsome number lower than expected in 1 subs...   True
# 115  chromsome number higher than expected in 3 sub...   True
# 127  chromsome number lower than expected in 1 subs...   True
# 147  chromsome number lower than expected in 1 subs...   True
#
# [9 rows x 45 columns]

# %%
results.loc[results['Error']==False] = results.loc[results['Error']==False].fillna(False)

# %%
results.head()
# Out:
#                       Cytogenetics  Number of cytogenetic abnormalities  \
# 0                        46,XX[25]                                  0.0
# 1        46,XY,del(11)(q14q23)[10]                                  1.0
# 2  46,XX,del(5)(q22q35)[8/46,XX[2]                                  NaN
# 3             45,X,-Y[17]/46,XY[3]                                  1.0
# 4             47,XY,+8[9]/46,XY[1]                                  1.0
#
#    Monosomy  Structural   "-Y"   "-X" del11q del12p del13q  del5q  ...  \
# 0       0.0         0.0  False  False  False  False  False  False  ...
# 1       0.0         0.0  False  False   True  False  False  False  ...
# 2       NaN         NaN    NaN    NaN    NaN    NaN    NaN    NaN  ...
# 3       1.0         0.0   True  False  False  False  False  False  ...
# 4       0.0         0.0  False  False  False  False  False  False  ...
#
#   inv(16) t(8;21) t(15;17) t(9;11) t(6;11) t(10;11) t(v;11) abnormal(17p)  \
# 0   False   False    False   False   False    False   False         False
# 1   False   False    False   False   False    False   False         False
# 2     NaN     NaN      NaN     NaN     NaN      NaN     NaN           NaN
# 3   False   False    False   False   False    False   False         False
# 4   False   False    False   False   False    False   False         False
#
#     Error description  Error
# 0               False  False
# 1               False  False
# 2  missing grammar: ]   True
# 3               False  False
# 4               False  False
#
# [5 rows x 45 columns]

# %%
#results.any()
# Out:
# Cytogenetics                            True
# Number of cytogenetic abnormalities     True
# Monosomy                                True
# Structural                              True
# "-Y"                                    True
# "-X"                                   False
# del11q                                  True
# del12p                                 False
# del13q                                  True
# del5q                                   True
# del7q                                   True
# idic(X)(q13)                           False
# isochromosome17q                       False
# Monosomy13                              True
# Monosomy17                              True
# Monosomy5                               True
# Monosomy7                               True
# t(1;3)                                 False
# t(11;16)(q23.3;p13.3)                  False
# t(12p)                                 False
# t(17p)                                 False
# t(2;11)                                False
# t(3;21)                                False
# t(3;5)                                 False
# t(5;10)                                False
# t(5;12)                                False
# t(5;17)                                False
# t(5;7)                                 False
# t(5q)                                  False
# t(1;22)                                False
# inv(3)                                  True
# t(3;3)                                 False
# t(6;9)                                 False
# t(9;22)                                 True
# t(16;16)                               False
# inv(16)                                False
# t(8;21)                                 True
# t(15;17)                                True
# t(9;11)                                False
# t(6;11)                                 True
# t(10;11)                               False
# t(v;11)                                 True
# abnormal(17p)                           True
# Error                                   True
# dtype: bool

# %%
#results.to_excel('Cytogenetics_output_V3.xlsx')

# %%
global
# Out:
# {'\\-Y': '"-Y"',
#  '\\-X': '"-X"',
#  'del\\(11\\)\\(q': 'del11q',
#  'del\\(12\\)\\(p': 'del12p',
#  'del\\(13\\)\\(q': 'del13q',
#  'del\\(5\\)\\(q': 'del5q',
#  'del\\(7\\)\\(q': 'del7q',
#  'idic\\(X\\)\\(q13\\)': 'idic(X)(q13)',
#  'isochromosome\\(17\\)\\(q': 'isochromosome17q',
#  '\\-13': 'Monosomy13',
#  '\\-17': 'Monosomy17',
#  '\\-5': 'Monosomy5',
#  '\\-7': 'Monosomy7',
#  't\\(1;3\\)': 't(1;3)',
#  't\\(11;16\\)\\(q23\\.3;p13\\.3\\)': 't(11;16)(q23.3;p13.3)',
#  't\\(\\(12\\)\\(p\\)': 't(12p)',
#  't\\(\\(17\\)\\(p\\)': 't(17p)',
#  't\\(2;11\\)': 't(2;11)',
#  't\\(3;21\\)': 't(3;21)',
#  't\\(3;5\\)': 't(3;5)',
#  't\\(5;10\\)': 't(5;10)',
#  't\\(5;12\\)': 't(5;12)',
#  't\\(5;17\\)': 't(5;17)',
#  't\\(5;7\\)': 't(5;7)',
#  't\\(\\(5\\)\\(q\\)': 't(5q)',
#  't\\(1;22\\)': 't(1;22)',
#  'inv\\(3\\)': 'inv(3)',
#  't\\(3;3\\)': 't(3;3)',
#  't\\(6;9\\)': 't(6;9)',
#  't\\(9;22\\)': 't(9;22)',
#  't\\(16;16\\)': 't(16;16)',
#  'inv\\(16\\)': 'inv(16)',
#  't\\(8;21\\)': 't(8;21)',
#  't\\(15;17\\)': 't(15;17)',
#  't\\(9;11\\)': 't(9;11)',
#  't\\(6;11\\)': 't(6;11)',
#  't\\(10;11\\)': 't(10;11)',
#  't\\(\\d+;11\\)': 't(v;11)'}

# %%
def download_link(object_to_download, download_filename, download_link_text):
    """
    Generates a link to download the given object_to_download.

    object_to_download (str, pd.DataFrame):  The object to be downloaded.
    download_filename (str): filename and extension of file. e.g. mydata.csv, some_txt_output.txt
    download_link_text (str): Text to display for download link.

    Examples:
    download_link(YOUR_DF, 'YOUR_DF.csv', 'Click here to download data!')
    download_link(YOUR_STRING, 'YOUR_STRING.txt', 'Click here to download your text!')

    """
    if isinstance(object_to_download,pd.DataFrame):
        object_to_download = object_to_download.to_csv(index=False)

    # some strings <-> bytes conversions necessary here
    b64 = base64.b64encode(object_to_download.encode()).decode()

    return f'<a href="data:file/txt;base64,{b64}" download="{download_filename}">{download_link_text}</a>'

# %%
st.write(results)

# %%
if st.button('Download Dataframe as CSV'):
    tmp_download_link = download_link(results, 'YOUR_DF.csv', 'Click here to download your data!')
    st.markdown(tmp_download_link, unsafe_allow_html=True)
